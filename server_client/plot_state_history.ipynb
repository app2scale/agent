# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

state_history = pd.read_csv("../server_client/state_history.csv")

colors = ['red', 'blue', 'green']
plt.hist(state_history.iloc[:,:3], 30, histtype='bar', color=colors, label=["replica", "cpu","heap"])
plt.legend(prop={'size': 10})

plt.show()
