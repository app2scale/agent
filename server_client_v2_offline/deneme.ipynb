# %%
import json

file_path = "/Users/hasan.nayir/ray_results/DQN_None_2024-01-10_16-16-00j_n0gr58/result.json"
data_list = []


with open(file_path, 'r') as json_file:
    for line in json_file:
        try:
            data = json.loads(line)
            data_list.append(data)
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")

# %%
data_list[0]
# Out:
# {'custom_metrics': {},
#  'episode_media': {},
#  'info': {'learner': {'default_policy': {'learner_stats': {'allreduce_latency': 0.0,
#      'grad_gnorm': 6.511293888092041,
#      'mean_q': 0.23992019891738892,
#      'min_q': -0.4558943808078766,
#      'max_q': 0.9803215265274048,
#      'cur_lr': 0.0001},
#     'td_error': [-1.5667319297790527,
#      -1.7234982252120972,
#      -1.457572340965271,
#      -0.8683619499206543,
#      -1.8436158895492554,
#      -1.6251142024993896,
#      -1.316399335861206,
#      -1.2053078413009644,
#      -1.5718605518341064,
#      -1.068406581878662,
#      -1.0410436391830444,
#      -1.3731567859649658,
#      -1.0825084447860718,
#      -1.2644219398498535,
#      -1.1140844821929932,
#      -1.1677143573760986,
#      -1.185604453086853,
#      -1.289114236831665,
#      -1.3235465288162231,
#      -0.9036967754364014,
#      -0.9178676605224609,
#      -0.9036967754364014,
#      -1.708865761756897,
#      -1.3879492282867432,
# ...

# %%
"mean_q" in data_list[0].keys()
# Out:
# False

# %%
from gymnasium.spaces import Discrete, Box
import numpy as np

asd =Box(low=np.array([1, 4, 4, 0, 0]), high=np.array([6, 9, 9, 200, 200]), dtype=np.float32)

ff  = asd.sample()
# Out:
# /Users/hasan.nayir/miniconda3/envs/rl_lib/lib/python3.9/site-packages/gymnasium/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
ff =np.append(ff, [50,50])
ff
# Out:
# array([  2.50456452,   7.69238567,   6.16376019, 114.05486298,
#         20.5925808 ,  50.        ,  50.        ])
